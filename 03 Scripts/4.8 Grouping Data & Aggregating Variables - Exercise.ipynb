# %% [markdown]
# # Exercise

# %%
# Import libraries
import pandas as pd
import numpy as np
import os

# %%
path = r'C:\Users\Josepa Cusidó\092022 Instacart Basket Analysis'

# %%
ords_prods_merge = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'Orders_and_Products_merged.pkl'))

# %%
ords_prods_merge.groupby('department_id').agg({'order_number': ['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 1                16.559358
# 2                18.413176
# 3                18.279600
# 4                18.915890
# 5                16.497751
# 6                17.609390
# 7                18.303975
# 8                16.383301
# 9                17.022963
# 10               21.227447
# 11               17.311768
# 12               16.953613
# 13               17.727470
# 14               17.898097
# 15               17.290123
# 16               18.757796
# 17               16.808683
# 18               20.336389
# 19               18.258620
# 20               17.578959
# 21               23.644477

# %% [markdown]
# In the subset we only had 8 departments, whereas here we have all the 21 departments included.

# %% [markdown]
# # Loyalty flag

# %%
ords_prods_merge['max_order'] = ords_prods_merge.groupby(['user_id'])['order_number'].transform(np.max)

# %%
ords_prods_merge.loc[ords_prods_merge['max_order'] > 40, 'loyalty_flag'] = 'Loyal customer'

# %%
ords_prods_merge.loc[(ords_prods_merge['max_order'] <= 40) & (ords_prods_merge['max_order'] > 10), 'loyalty_flag'] = 'Regular customer'

# %%
ords_prods_merge.loc[ords_prods_merge['max_order'] <= 10, 'loyalty_flag'] = 'New customer'

# %%
ords_prods_merge['loyalty_flag'].value_counts(dropna = False)
# Out:
# Regular customer    15081691
# Loyal customer      10095381
# New customer         5151691
# Name: loyalty_flag, dtype: int64

# %%
ords_prods_merge.groupby('loyalty_flag').agg({'prices': ['mean', 'min', 'max']})
# Out:
#                      prices
#                        mean  min      max
# loyalty_flag
# Loyal customer    10.402162  1.0  99999.0
# New customer      13.396333  1.0  99999.0
# Regular customer  12.546842  1.0  99999.0

# %% [markdown]
# Whereas the min and max values for the three categories are the same, the mean is higher for new customers (13,4), which means that they spend slightly more on products than regular (12,5) and loyal (10,4) customers.

# %%
ords_prods_merge['mean_prices'] = ords_prods_merge.groupby(['user_id'])['prices'].transform(np.mean)

# %%
ords_prods_merge.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_time  \
# 0   2398795        1             2                   3           7
# 1    473747        1             3                   3          12
# 2   2254736        1             4                   4           7
# 3    431534        1             5                   4          15
# 4   3367565        1             6                   2           7
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                    15.0         196                  1          1
# 1                    21.0         196                  1          1
# 2                    29.0         196                  1          1
# 3                    28.0         196                  1          1
# 4                    19.0         196                  1          1
#
#    Unnamed: 0  ... department_id  prices  _merge    price_range_loc  \
# 0         195  ...             7     9.0    both  Mid-range product
# ...

# %% [markdown]
# # Spending flag

# %%
ords_prods_merge.loc[ords_prods_merge['mean_prices'] < 10, 'spending_flag'] = 'Low spender'

# %%
ords_prods_merge.loc[ords_prods_merge['mean_prices'] > 10, 'spending_flag'] = 'High spender'

# %%
pd.options.display.max_rows = None

# %%
ords_prods_merge.head(100)
# Out:
#     order_id  user_id  order_number  orders_day_of_week  order_time  \
# 0    2398795        1             2                   3           7
# 1     473747        1             3                   3          12
# 2    2254736        1             4                   4           7
# 3     431534        1             5                   4          15
# 4    3367565        1             6                   2           7
# 5     550135        1             7                   1           9
# 6    3108588        1             8                   1          14
# 7    2295261        1             9                   1          16
# 8    2550362        1            10                   4           8
# 9    2968173       15            15                   1           9
# 10   1870022       15            17                   2          16
# 11   1911383       15            18                   2          11
# 12   2715276       15            21                   1           9
# ...

# %%
ords_prods_merge['spending_flag'].value_counts(dropna = False)
# Out:
# Low spender     29730505
# High spender      597858
# NaN                  400
# Name: spending_flag, dtype: int64

# %% [markdown]
# # Frecuency flag

# %%
ords_prods_merge['median_days_prior_order'] = ords_prods_merge.groupby(['user_id'])['days_since_prior_order'].transform(np.median)

# %%
ords_prods_merge.loc[ords_prods_merge['median_days_prior_order'] > 20, 'frecuency_flag'] = 'Non-frequent customer'

# %%
ords_prods_merge.loc[(ords_prods_merge['median_days_prior_order'] <= 20) & (ords_prods_merge['median_days_prior_order'] > 10), 'frecuency_flag'] = 'Regular customer'

# %%
ords_prods_merge.loc[ords_prods_merge['median_days_prior_order'] <= 10, 'frecuency_flag'] = 'Frequent customer'

# %%
ords_prods_merge.head(100)
# Out:
#     order_id  user_id  order_number  orders_day_of_week  order_time  \
# 0    2398795        1             2                   3           7
# 1     473747        1             3                   3          12
# 2    2254736        1             4                   4           7
# 3     431534        1             5                   4          15
# 4    3367565        1             6                   2           7
# 5     550135        1             7                   1           9
# 6    3108588        1             8                   1          14
# 7    2295261        1             9                   1          16
# 8    2550362        1            10                   4           8
# 9    2968173       15            15                   1           9
# 10   1870022       15            17                   2          16
# 11   1911383       15            18                   2          11
# 12   2715276       15            21                   1           9
# ...

# %%
ords_prods_merge['frecuency_flag'].value_counts(dropna = False)
# Out:
# Frequent customer        20675290
# Regular customer          6594542
# Non-frequent customer     3058931
# Name: frecuency_flag, dtype: int64

# %%
#Exporting Data
ords_prods_merge.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'Orders_and_Products_merged.pkl'))
