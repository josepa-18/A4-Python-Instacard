# %%
# Import libraries
import pandas as pd
import numpy as np
import os

# %%
path = r'C:\Users\Josepa Cusidó\092022 Instacart Basket Analysis'

# %%
ords_prods_merge = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'Orders and Products merged.pkl'))

# %%
# Create a Subset
df = ords_prods_merge[:1000000]

# %%
# Define a function
def price_label(row):

  if row['prices'] <= 5:
    return 'Low-range product'
  elif (row['prices'] > 5) and (row['prices'] <= 15):
    return 'Mid-range product'
  elif row['prices'] > 15:
    return 'High range'
  else: return 'Not enough data'

# %%
ords_prods_merge.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_time  \
# 0   2398795        1             2                   3           7
# 1    473747        1             3                   3          12
# 2   2254736        1             4                   4           7
# 3    431534        1             5                   4          15
# 4   3367565        1             6                   2           7
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                    15.0         196                  1          1
# 1                    21.0         196                  1          1
# 2                    29.0         196                  1          1
# 3                    28.0         196                  1          1
# 4                    19.0         196                  1          1
#
#    Unnamed: 0 product_name  aisle_id  department_id  prices _merge
# 0         195         Soda        77              7     9.0   both
# ...

# %%
df['price_range'] = df.apply(price_label, axis=1)
# Out:
# C:\Users\JOSEPA~1\AppData\Local\Temp/ipykernel_11644/2848743372.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price_range'] = df.apply(price_label, axis=1)

# %%
df['price_range'].value_counts(dropna = False)
# Out:
# Mid-range product    631969
# Low-range product    368031
# Name: price_range, dtype: int64

# %%
df['prices'].max()
# Out:
# 14.0

# %%
# loc() Function
df.loc[df['prices'] > 15, 'price_range_loc'] = 'High-range product'
# Out:
# C:\Users\JOSEPA~1\AppData\Local\Temp/ipykernel_11644/2519450130.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[df['prices'] > 15, 'price_range_loc'] = 'High-range product'

# %%
df.loc[(df['prices'] <= 15) & (df['prices'] > 5), 'price_range_loc'] = 'Mid-range product'

# %%
df.loc[df['prices'] <= 5, 'price_range_loc'] = 'Low-range product'

# %%
df['price_range_loc'].value_counts(dropna = False)
# Out:
# Mid-range product    631969
# Low-range product    368031
# Name: price_range_loc, dtype: int64

# %%
ords_prods_merge.loc[ords_prods_merge['prices'] > 15, 'price_range_loc'] = 'High-range product'

# %%
ords_prods_merge.loc[(ords_prods_merge['prices'] <= 15) & (ords_prods_merge['prices'] > 5), 'price_range_loc'] = 'Mid-range product'

# %%
ords_prods_merge.loc[ords_prods_merge['prices'] <= 5, 'price_range_loc'] = 'Low-range product'

# %%
# For Loops
ords_prods_merge['orders_day_of_week'].value_counts(dropna = False)
# Out:
# 0    5779087
# 1    5303718
# 6    4190948
# 5    3952326
# 2    3947564
# 3    3600589
# 4    3554531
# Name: orders_day_of_week, dtype: int64

# %%
result = []

for value in ords_prods_merge["orders_day_of_week"]:
  if value == 0:
    result.append("Busiest day")
  elif value == 4:
    result.append("Least busy")
  else:
    result.append("Regularly busy")

# %%
result
# Out:
# ['Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
# ...

# %%
# New column with the loop result
ords_prods_merge['busiest_day'] = result

# %%
ords_prods_merge['busiest_day'].value_counts(dropna = False)
# Out:
# Regularly busy    20995145
# Busiest day        5779087
# Least busy         3554531
# Name: busiest_day, dtype: int64

# %% [markdown]
# # Exercise

# %%
# Column for busiest days

result = []

for value in ords_prods_merge["orders_day_of_week"]:
  if value == 0:
    result.append("Busiest days")
  elif value == 1:
    result.append("Busiest days")
  elif value == 3:
    result.append("Least busy days")
  elif value == 4:
    result.append("Least busy days")
  else:
    result.append("Regularly busy")

# %%
# New column with the loop result
ords_prods_merge['busiest_days'] = result

# %%
ords_prods_merge['busiest_days'].value_counts(dropna = False)
# Out:
# Regularly busy     12090838
# Busiest days       11082805
# Least busy days     7155120
# Name: busiest_days, dtype: int64

# %%
ords_prods_merge.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_time  \
# 0   2398795        1             2                   3           7
# 1    473747        1             3                   3          12
# 2   2254736        1             4                   4           7
# 3    431534        1             5                   4          15
# 4   3367565        1             6                   2           7
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                    15.0         196                  1          1
# 1                    21.0         196                  1          1
# 2                    29.0         196                  1          1
# 3                    28.0         196                  1          1
# 4                    19.0         196                  1          1
#
#    Unnamed: 0 product_name  aisle_id  department_id  prices _merge  \
# 0         195         Soda        77              7     9.0   both
# ...

# %% [markdown]
# With the new extra column for the two busiest and the two least busy days, there are almost as many values for busy days as for regularly busy days

# %%
# Busiest hours of the day
ords_prods_merge['order_time'].value_counts(dropna = False)
# Out:
# 10    2593725
# 11    2564597
# 14    2517238
# 15    2487586
# 13    2487500
# 12    2445841
# 16    2364969
# 9     2311334
# 17    1943858
# 8     1622394
# 18    1520954
# 19    1169224
# 20     910005
# 7      844665
# 21     746254
# 22     592432
# 23     375889
# 6      274801
# 0      203460
# 1      108110
# 5       82706
# 2       63961
# 4       49400
# 3       47860
# Name: order_time, dtype: int64

# %%
# Column for busiest hours

result = []

for value in ords_prods_merge["order_time"]:
  if value >= 9 and value <= 16:
    result.append("Most orders")
  elif value >= 0 and value <= 6:
    result.append("Fewest orders")
  elif value == 23:
    result.append("Fewest orders")
  else:
    result.append("Average orders")

# %%
# New column with the loop result
ords_prods_merge['busiest_period_of_day'] = result

# %%
# Frecuency for busiest_period_of_day
ords_prods_merge['busiest_period_of_day'].value_counts(dropna = False)
# Out:
# Most orders       19772790
# Average orders     9349786
# Fewest orders      1206187
# Name: busiest_period_of_day, dtype: int64

# %%
ords_prods_merge.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_time  \
# 0   2398795        1             2                   3           7
# 1    473747        1             3                   3          12
# 2   2254736        1             4                   4           7
# 3    431534        1             5                   4          15
# 4   3367565        1             6                   2           7
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                    15.0         196                  1          1
# 1                    21.0         196                  1          1
# 2                    29.0         196                  1          1
# 3                    28.0         196                  1          1
# 4                    19.0         196                  1          1
#
#    Unnamed: 0 product_name  aisle_id  department_id  prices _merge  \
# 0         195         Soda        77              7     9.0   both
# ...

# %%
#Exporting Data
ords_prods_merge.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'Orders_and_Products_merged.pkl'))
